# %%
import sys
sys.path.append('..')

import os
os.environ['THEANO_FLAGS'] = 'mode=FAST_RUN,device=gpu,floatX=float32,nvcc.flags=-D_FORCE_INLINES'

import matplotlib
import matplotlib.pyplot as plt
from ClusteringExperiment import ClusteringExperiment
import dataset_utils as utils
from nolearn.lasagne.visualize import plot_loss

exper = utils.load_single('CE_ConvAutoencder_700_ght.zip')
#Loss function
plot_loss(exper._nnet.ae)
plt.show()
# Out:
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 0: GeForce GTX 950 (CNMeM is disabled, cuDNN not available)

# %%
#Input/output eval
train = exper._training_dataset.get_items()
output = exper._output.get_items()
utils.plot_pixel_image(train[0],output[0],64,64)

# %%
#Cluster distirbution
lens = []
for i in exper._clustering._clustering_dist:
    lens.append(i[1])
plt.plot(lens)
plt.show()
